# %%
import os 
import pandas as pd

# %%
Dropbox_path="/mnt/c/Users/ETTINA03/NYU Langone Health Dropbox/April Jauhal/Shenhav_Lab"
Fig_path = os.path.join(Dropbox_path, "IMiC/Figures")

# %%
# %run "ml_plotting_functions.py"

# %%
# Load annotated/unannotated MS2 data
ut_misame_waz_annotated = pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/misame_waz_annotated_feats_gbm.pickle'))
ut_misame_waz_unannotated = pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/misame_waz_not_annotated_feats_gbm.pickle'))
ut_vital_waz_annotated = pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/vital_waz_annotated_feats_gbm.pickle'))
ut_vital_waz_unannotated = pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/vital_waz_not_annotated_feats_gbm.pickle'))
ut_child_waz_annotated = pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/child_waz_annotated_feats_gbm.pickle'))
ut_child_waz_unannotated = pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/child_waz_not_annotated_feats_gbm.pickle'))

# %%
figS3_1=compare_plot_ROC_AUC([ut_misame_waz_annotated, ut_misame_waz_unannotated], ['Annotated', 'Unannotated'], type='mean', plot_title="MISAME Month 4 WAZ")
figS3_1.savefig(os.path.join(Fig_path, 'FigureS3_pt1.pdf'), dpi=600)
figS3_2=compare_plot_ROC_AUC([ut_vital_waz_annotated, ut_vital_waz_unannotated], ['Annotated', 'Unannotated'], type='mean', plot_title="Mumta-LW Month 4 WAZ")
figS3_2.savefig(os.path.join(Fig_path, 'FigureS3_pt2.pdf'), dpi=600)
figS3_3=compare_plot_ROC_AUC([ut_child_waz_annotated, ut_child_waz_unannotated], ['Annotated', 'Unannotated'], type='mean', plot_title="CHILD Month 3 WAZ")
figS3_3.savefig(os.path.join(Fig_path, 'FigureS3_pt3.pdf'), dpi=600)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...
