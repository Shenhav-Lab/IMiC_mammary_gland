# %%
import os 
import pandas as pd

# %%
Dropbox_path="/mnt/c/Users/ETTINA03/NYU Langone Health Dropbox/April Jauhal/Shenhav_Lab"
Fig_path = os.path.join(Dropbox_path, "IMiC/Figures")

# %%
# Load plotting functions
# %run "ml_plotting_functions.py"

# %%
# Load targeted BEP data
targeted_pickle_path = os.path.join(Dropbox_path, "IMiC/Code/targeted_metabolomics_data_processing/pickles/")
misame_all_targeted = pd.read_pickle(os.path.join(targeted_pickle_path,'misame_BEP_uM_gbm_ae.pickle'))
misame_bep_cs_targeted = pd.read_pickle(os.path.join(targeted_pickle_path,'misame_BEP_topfeats_ae_new.pickle')) 
vital_all_targeted = pd.read_pickle(os.path.join(targeted_pickle_path,'vital_BEP_uM_gbm_ae.pickle'))
vital_bep_cs_targeted = pd.read_pickle(os.path.join(targeted_pickle_path,'vital_BEP_topfeats_ae_new.pickle'))  

# Load targeted WAZ data
misame_childsigWAZ=pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/misame_waz_childsig_gbm.pickle'))
vital_childsigWAZ=pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/vital_waz_childsig_gbm.pickle'))
child_childsigWAZ=pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/child_waz_childsig_gbm.pickle'))
misame_tar_csWAZ=pd.read_pickle(os.path.join(Dropbox_path, "IMiC/Code/targeted_metabolomics_data_processing/pickles/misame_wazmargin_crosswaz_ae_pure.pickle"))
vital_tar_csWAZ=pd.read_pickle(os.path.join(Dropbox_path, "IMiC/Code/targeted_metabolomics_data_processing/pickles/vital_wazmargin_crosswaz_ae_pure.pickle"))
child_tar_csWAZ=pd.read_pickle(os.path.join(Dropbox_path, "IMiC/Code/targeted_metabolomics_data_processing/pickles/child_wazmargin_crosswaz_ae_pure.pickle"))

# %%
# Load untargeted data
misame_untar_csWAZ=pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/misame_cs_overlap_sig_feats_gbm.pickle'))
vital_untar_csWAZ=pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/vital_waz_cs_overlap_sig_feats_gbm.pickle'))
child_untar_csWAZ=pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/child_waz_cs_overlap_sig_feats_gbm.pickle'))
ut_misame_bep_cs = pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/misame_BEP_fromMeanMaxUnionBEP_meta_for_ML_gbm_sl1.pickle'))
ut_vital_bep_cs = pd.read_pickle(os.path.join(Dropbox_path, 'IMiC/Code/machine_learning/pickles/vital_BEP_fromMeanMaxUnionBEP_meta_for_ML_gbm_sl1.pickle'))

# %%
# Load 104 feature data
misame_waz_104 = pd.read_pickle(os.path.join(Dropbox_path, "IMiC/Code/machine_learning/pickles/misame_all_gbm.pickle"))
vital_waz_104 = pd.read_pickle(os.path.join(Dropbox_path, "IMiC/Code/machine_learning/pickles/vital_waz_all_gbm.pickle"))
child_waz_104 = pd.read_pickle(os.path.join(Dropbox_path, "IMiC/Code/machine_learning/pickles/child_WAZ_all_gbm.pickle"))
misame_bep_104 = pd.read_pickle(os.path.join(Dropbox_path, "IMiC/Code/machine_learning/pickles/misame_bep_all_gbm.pickle"))
vital_bep_104 = pd.read_pickle(os.path.join(Dropbox_path, "IMiC/Code/machine_learning/pickles/vital_bep_all_gbm.pickle"))

# %%
figS3_1=compare_plot_ROC_AUC([ut_misame_waz_annotated, ut_misame_waz_unannotated], ['Annotated', 'Unannotated'], type='mean', plot_title="MISAME Month 4 WAZ")
figS3_1.savefig(os.path.join(Fig_path, 'FigureS3_pt1.pdf'), dpi=600)
figS3_2=compare_plot_ROC_AUC([ut_vital_waz_annotated, ut_vital_waz_unannotated], ['Annotated', 'Unannotated'], type='mean', plot_title="Mumta-LW Month 4 WAZ")
figS3_2.savefig(os.path.join(Fig_path, 'FigureS3_pt2.pdf'), dpi=600)
figS3_3=compare_plot_ROC_AUC([ut_child_waz_annotated, ut_child_waz_unannotated], ['Annotated', 'Unannotated'], type='mean', plot_title="CHILD Month 3 WAZ")
figS3_3.savefig(os.path.join(Fig_path, 'FigureS3_pt3.pdf'), dpi=600)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
fig3A1=compare_plot_ROC_AUC([misame_bep_cs_targeted, ut_misame_bep_cs, misame_bep_104], ['Targeted', 'Untargeted', 'Untargeted (MS2)'], type='mean', plot_title="MISAME BEP")
fig3A1.savefig(os.path.join(Fig_path, 'FigureS3A1.pdf'), dpi=600)
fig3A2=compare_plot_ROC_AUC([vital_bep_cs_targeted, ut_vital_bep_cs, vital_bep_104], ['Targeted', 'Untargeted', 'Untargeted (MS2)'], type='mean', plot_title="Mumta-LW BEP")
fig3A2.savefig(os.path.join(Fig_path, 'FigureS3A2.pdf'), dpi=600)
fig3A3=compare_plot_ROC_AUC([misame_tar_csWAZ, misame_untar_csWAZ, misame_waz_104], ['Targeted', 'Untargeted', 'Untargeted (MS2)'], type='mean', plot_title="MISAME WAZ")
fig3A3.savefig(os.path.join(Fig_path, 'FigureS3A3.pdf'), dpi=600)
fig3A4=compare_plot_ROC_AUC([vital_tar_csWAZ, vital_untar_csWAZ, vital_waz_104], ['Targeted', 'Untargeted', 'Untargeted (MS2)'], type='mean', plot_title="Mumta-LW WAZ")
fig3A4.savefig(os.path.join(Fig_path, 'FigureS3A4.pdf'), dpi=600)
fig3A5=compare_plot_ROC_AUC([child_tar_csWAZ, child_untar_csWAZ, child_waz_104], ['Targeted', 'Untargeted', 'Untargeted (MS2)'], type='mean', plot_title="CHILD WAZ")
fig3A5.savefig(os.path.join(Fig_path, 'FigureS3A5.pdf'), dpi=600)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...
